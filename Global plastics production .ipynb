# %%
import pandas as pd
import numpy as np 
import random

# %%
df=pd.read_csv('D:\\csv\\global-plastics-production.csv')
df
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 0   World  OWID_WRL  1950                                      2000000
# 1   World  OWID_WRL  1951                                      2000000
# 2   World  OWID_WRL  1952                                      2000000
# 3   World  OWID_WRL  1953                                      3000000
# 4   World  OWID_WRL  1954                                      3000000
# ..    ...       ...   ...                                          ...
# 61  World  OWID_WRL  2011                                    325000000
# 62  World  OWID_WRL  2012                                    338000000
# 63  World  OWID_WRL  2013                                    352000000
# 64  World  OWID_WRL  2014                                    367000000
# 65  World  OWID_WRL  2015                                    381000000
#
# [66 rows x 4 columns]

# %%
data.describe()
# Out:
# count    4.0
# mean     0.0
# std      0.0
# min      0.0
# 25%      0.0
# 50%      0.0
# 75%      0.0
# max      0.0
# dtype: float64

# %% [markdown]
# ## 1.Clean the dataset

# %%
pd.set_option('display.max_column',None)
pd.set_option('display.max_row',None)
print(df)
# Out:
#    Entity      Code  Year  Global plastics production (million tonnes)
# 0   World  OWID_WRL  1950                                      2000000
# 1   World  OWID_WRL  1951                                      2000000
# 2   World  OWID_WRL  1952                                      2000000
# 3   World  OWID_WRL  1953                                      3000000
# 4   World  OWID_WRL  1954                                      3000000
# 5   World  OWID_WRL  1955                                      4000000
# 6   World  OWID_WRL  1956                                      5000000
# 7   World  OWID_WRL  1957                                      5000000
# 8   World  OWID_WRL  1958                                      6000000
# 9   World  OWID_WRL  1959                                      7000000
# 10  World  OWID_WRL  1960                                      8000000
# 11  World  OWID_WRL  1961                                      9000000
# ...

# %% [markdown]
# ### 1.Q  find how much NAN value

# %%
df.isnull()
# Out:
#     Entity   Code   Year  Global plastics production (million tonnes)
# 0    False  False  False                                        False
# 1    False  False  False                                        False
# 2    False  False  False                                        False
# 3    False  False  False                                        False
# 4    False  False  False                                        False
# 5    False  False  False                                        False
# 6    False  False  False                                        False
# 7    False  False  False                                        False
# 8    False  False  False                                        False
# 9    False  False  False                                        False
# 10   False  False  False                                        False
# 11   False  False  False                                        False
# ...

# %%
data=df.count()
data
# Out:
# Entity                                         66
# Code                                           66
# Year                                           66
# Global plastics production (million tonnes)    66
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Entity                                         0
# Code                                           0
# Year                                           0
# Global plastics production (million tonnes)    0
# dtype: int64

# %% [markdown]
# ## Q2. how many plastic production and which year

# %%
data=df.groupby('Year').sum()
data
# Out:
#       Global plastics production (million tonnes)
# Year
# 1950                                      2000000
# 1951                                      2000000
# 1952                                      2000000
# 1953                                      3000000
# 1954                                      3000000
# 1955                                      4000000
# 1956                                      5000000
# 1957                                      5000000
# 1958                                      6000000
# 1959                                      7000000
# 1960                                      8000000
# 1961                                      9000000
# 1962                                     11000000
# 1963                                     13000000
# 1964                                     15000000
# 1965                                     17000000
# 1966                                     20000000
# 1967                                     23000000
# ...

# %% [markdown]
# ## Q3.Which year plastic production is more?

# %%
df['Year'].max()
# Out:
# 2015

# %% [markdown]
# ## Q4. Which year plastic production is less?

# %%
df['Year'].min()
# Out:
# 1950

# %% [markdown]
# ## Q5 Which year in has repeated plastic production

# %%
data1=df.groupby('Global plastics production (million tonnes)').get_group(2000000)
data2=df.groupby('Global plastics production (million tonnes)').get_group(3000000)
data3=df.groupby('Global plastics production (million tonnes)').get_group(5000000)
display(data1,data2,data3)
# Out:
#   Entity      Code  Year  Global plastics production (million tonnes)
# 0  World  OWID_WRL  1950                                      2000000
# 1  World  OWID_WRL  1951                                      2000000
# 2  World  OWID_WRL  1952                                      2000000
#   Entity      Code  Year  Global plastics production (million tonnes)
# 3  World  OWID_WRL  1953                                      3000000
# 4  World  OWID_WRL  1954                                      3000000
#   Entity      Code  Year  Global plastics production (million tonnes)
# 6  World  OWID_WRL  1956                                      5000000
# 7  World  OWID_WRL  1957                                      5000000

# %% [markdown]
# ## Q6. how much increase production per year

# %%
plt.xlabel('Year',size=15)
plt.ylabel('Global plastics production (million tonnes)',size=15)
plt.title('production per year',size=18,color='r')
plt.plot(df['Global plastics production (million tonnes)'],df['Year'],'--g',linewidth=3,markersize=6)
plt.grid(color='k',linestyle='--',linewidth=1,markersize=10,axis='x')
